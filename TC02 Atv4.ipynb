# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from IPython.display import display
from abc import ABC, abstractmethod
from scipy.spatial import cKDTree # Para otimização do 1-NN
from typing import Dict, List, Tuple, Any
from compara_todos import compara_todos

# %% [markdown]
# # Testes

# %%
Nr = 50      # Número de rodadas
Ptrain = 80  # Percentual de treino

# %%
compara_todos('recfaces400PCA.dat', Nr, Ptrain)
# Out:
# --- INICIANDO AVALIAÇÃO DOS CLASSIFICADORES ---
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 7.15%
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 78.12%
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 94.67%
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 94.73%
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 78.61%
# Executando MaxCorr...
# Finalizado: MaxCorr. Acurácia Média: 78.79%
# Executando DMC...
# Finalizado: DMC. Acurácia Média: 76.73%
# Executando NN1...
# Finalizado: NN1. Acurácia Média: 76.85%
# \n--- AVALIAÇÃO FINALIZADA ---\n
# --- TABELA DE RESULTADOS ---
#                                            Média (%)  Mínimo (%)  Máximo (%)  \
# QDA (Quadrático)                                7.15        0.00       15.15
# Variante 1 (Tikhonov λ=0.01)                   78.12       63.64       90.91
# Variante 2 (Matriz de Covariância Pooled)      94.67       81.82      100.00
# Variante 3 (Friedman λ=0.5)                    94.73       87.88      100.00
# Variante 4 (Naive Bayes)                       78.61       63.64       96.97
# MaxCorr                                        78.79       66.67       93.94
# DMC                                            76.73       63.64       90.91
# 1-NN                                           76.85       63.64       90.91
#
#                                            Mediana (%)  Desvio Padrão  \
# QDA (Quadrático)                                  6.06           3.92
# Variante 1 (Tikhonov λ=0.01)                     78.79           6.36
# Variante 2 (Matriz de Covariância Pooled)        95.45           3.95
# Variante 3 (Friedman λ=0.5)                      93.94           3.31
# Variante 4 (Naive Bayes)                         78.79           6.95
# MaxCorr                                          78.79           6.53
# DMC                                              75.76           7.23
# 1-NN                                             75.76           5.84
#
#                                            Tempo (s)
# QDA (Quadrático)                                0.22
# Variante 1 (Tikhonov λ=0.01)                    0.17
# Variante 2 (Matriz de Covariância Pooled)       0.29
# Variante 3 (Friedman λ=0.5)                     0.34
# Variante 4 (Naive Bayes)                        0.13
# MaxCorr                                         0.02
# DMC                                             0.02
# 1-NN                                            0.01
# /tmp/ipykernel_53217/3513297870.py:62: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(all_tx_ok, patch_artist=True, labels=classifier_names)
# /tmp/ipykernel_53217/3513297870.py:65: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('viridis', len(all_tx_ok))
