# %%
# %reload_ext autoreload
# %autoreload 2
from compara_todos import compara_todos

# %% [markdown]
# # Testes

# %%
Nr = 50      # Número de rodadas
Ptrain = 80  # Percentual de treino

# %%
results = compara_todos('recfaces400PCA98var.dat', Nr, Ptrain)
# Out:
# --- CARREGANDO DADOS DE 'recfaces400PCA98var.dat' ---
#
# --- INICIANDO AVALIAÇÃO DOS CLASSIFICADORES (50 repetições, 80% treino) ---
# Avaliando: QDA (Quadrático)...
# Classificador: QDA (Quadrático)
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 2.00%
# Avaliando: Variante 1 (Tikhonov λ=0.01)...
# Classificador: Variante 1 (Tikhonov λ=0.01)
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 78.79%
# Avaliando: Variante 2 (Covariance Pooled)...
# Classificador: Variante 2 (Covariance Pooled)
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 93.52%
# Avaliando: Variante 3 (Friedman λ=0.5)...
# Classificador: Variante 3 (Friedman λ=0.5)
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 86.73%
# Avaliando: Variante 4 (Naive Bayes)...
# Classificador: Variante 4 (Naive Bayes)
# Executando QDA...
# Finalizado: QDA. Acurácia Média: 69.94%
# Avaliando: MaxCorr...
# Classificador: MaxCorr
# Executando MaxCorr...
# Finalizado: MaxCorr. Acurácia Média: 76.61%
# Avaliando: DMC...
# Classificador: DMC
# Executando DMC...
# Finalizado: DMC. Acurácia Média: 76.48%
# Avaliando: 1-NN...
# Classificador: 1-NN
# Executando NN1...
# Finalizado: NN1. Acurácia Média: 78.12%
#
# --- AVALIAÇÃO FINALIZADA ---
#
# --- TABELA DE RESULTADOS ---
#                                 Média (%)  Mínimo (%)  Máximo (%)  \
# QDA (Quadrático)                     2.00        0.00        9.09
# Variante 1 (Tikhonov λ=0.01)        78.79       63.64       90.91
# Variante 2 (Covariance Pooled)      93.52       75.76      100.00
# Variante 3 (Friedman λ=0.5)         86.73       72.73       96.97
# Variante 4 (Naive Bayes)            69.94       51.52       90.91
# MaxCorr                             76.61       63.64       90.91
# DMC                                 76.48       63.64       87.88
# 1-NN                                78.12       63.64       96.97
#
#                                 Mediana (%)  Desvio Padrão  Tempo (s)
# QDA (Quadrático)                       1.52           2.39       0.22
# Variante 1 (Tikhonov λ=0.01)          78.79           6.15       0.20
# Variante 2 (Covariance Pooled)        93.94           4.89       0.27
# Variante 3 (Friedman λ=0.5)           84.85           5.75       0.32
# Variante 4 (Naive Bayes)              69.70           8.20       0.19
# MaxCorr                               75.76           6.36       0.02
# DMC                                   75.76           6.43       0.02
# 1-NN                                  78.79           6.07       0.04

# %%
model_names = [
    "QDA (Quadrático)",
    "Variante 1 (Tikhonov λ=0.01)",
    "Variante 2 (Covariance Pooled)",
    "Variante 3 (Friedman λ=0.5)",
    "Variante 4 (Naive Bayes)"
]

for model in model_names:
    print(f"Postos das matrizes de covariância para {model}:")
    for i in results[1][model]["model_params"]["covariances_rank"]:
        print(results[1][model]["model_params"]["covariances_rank"][i])
# Out:
# Postos das matrizes de covariância para QDA (Quadrático):
# 8
# 7
# 7
# 8
# 7
# 7
# 8
# 9
# 6
# 6
# 9
# 7
# 6
# 9
# 8
# Postos das matrizes de covariância para Variante 1 (Tikhonov λ=0.01):
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# Postos das matrizes de covariância para Variante 2 (Covariance Pooled):
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# Postos das matrizes de covariância para Variante 3 (Friedman λ=0.5):
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# Postos das matrizes de covariância para Variante 4 (Naive Bayes):
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69
